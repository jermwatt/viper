# %% [markdown]
# # VipverGPT collab demo

# %% [markdown]
# The cell below provides a switch for executing install / setup commands on a local machine or on google collab.
#
# Note on google collab: at present (3/21/2024) only CPU runtime has required memory to run this demo.

# %%
# import standard libs
import os

# if on collab pull required subdirectories
if os.getenv("COLAB_RELEASE_TAG"): 

  # pull repository to collab 
  # !git clone --recurse-submodules https://github.com/cvlab-columbia/viper.git

  # export 
  # !export PATH=/usr/local/cuda/bin:$PATH

  # cd to viper home dir for main install
  os.chdir('/content/viper')
  # !bash setup.sh 

  # cd to /viper/GLIP for python setup
  os.chdir('/content/viper/GLIP')
  # !python setup.py clean --all build develop --user

  # install openai python apis
  # !pip install openai

  # to avoid ImportError: cannot import name 'is_directory' from 'PIL._util'
  # !pip install --upgrade pillow==6.2.2

  # RESTART RUNTIME for pillow downgrade to take effect
else:
  pass
# Out:
# fatal: destination path 'viper' already exists and is not an empty directory.
# setup_env.sh: line 1: conda: command not found
# setup_env.sh: line 2: conda: command not found
# setup_env.sh: line 3: conda: command not found
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-ty_1mlu5
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-ty_1mlu5
#   Resolved https://github.com/openai/CLIP.git to commit a9b1bf5920416aaeaec965c25dd9e8f98c864f16
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/openai/openai-python.git to /tmp/pip-req-build-14d0_h2g
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/openai-python.git /tmp/pip-req-build-14d0_h2g
#   Resolved https://github.com/openai/openai-python.git to commit 1d6142f376067e401492ca92ff88a08deb47d6ba
# ...

# %%
  # create a file api.key in /viper - add your openapi key to it 
  # you can do this via a terminal in collab on the lower left (to avoid copying
  # directly into a notebook)

  # alternatively uncomment and execute the code below (placing your
  # api key in this notebook is NOT RECOMMENDED)
  # os.chdir('/content/viper')
  # !touch api.key 
  # !echo YOUR_OPENAI_API_KEY_HERE > api.key

# %%
# # empty cache to free up GPU
# import torch
# torch.cuda.empty_cache()

# cd to main repo directory and import main simple library
import os
os.chdir('/content/viper')
from main_simple_lib import *
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 8
#       6 import os
#       7 os.chdir('/content/viper')
# ----> 8 from main_simple_lib import *
#
# File /content/viper/main_simple_lib.py:33
#      29 cache = Memory('cache/' if config.use_cache else None, verbose=0)
#      32 mp.set_start_method('spawn', force=True)
# ---> 33 from vision_processes import forward, finish_all_consumers  # This import loads all the models. May take a while
#      34 from image_patch import *
#      35 from video_segment import *
#
# File /content/viper/vision_processes.py:177
#     175     for process_name_ in model_class_.list_processes():
# ...
